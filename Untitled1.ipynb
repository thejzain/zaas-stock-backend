# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# ignore harmless warnings
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_excel('poland_inflation_ratings.xlsx')
dataset.tail()
# Out:
#     Year       1       2       3       4       5       6       7       8  \
# 7   2019  102.94  105.65  117.65  119.18  125.65  129.98  137.68  137.78
# 8   2020  165.04  175.65  143.61  173.21  180.76  194.78  208.04  222.64
# 9   2021  242.67  233.56  234.81  258.26  257.86  267.60  280.60  292.43
# 10  2022  314.46  305.51  279.78  281.78  267.89  270.41  265.45  275.10
# 11  2023  238.45  265.34  275.43  298.43     NaN     NaN     NaN     NaN
#
#          9      10      11      12
# 7   138.99  146.40  149.90  150.78
# 8   206.45  220.76  216.51  217.56
# 9   300.21  306.50  335.45  340.10
# 10  241.55  228.17  247.87  229.87
# 11     NaN     NaN     NaN     NaN

# %%
dataset = pd.read_excel(r'poland_inflation_ratings.xlsx')
dataset.tail()
# Out:
#     Year       1       2       3       4       5       6       7       8  \
# 7   2019  102.94  105.65  117.65  119.18  125.65  129.98  137.68  137.78
# 8   2020  165.04  175.65  143.61  173.21  180.76  194.78  208.04  222.64
# 9   2021  242.67  233.56  234.81  258.26  257.86  267.60  280.60  292.43
# 10  2022  314.46  305.51  279.78  281.78  267.89  270.41  265.45  275.10
# 11  2023  238.45  265.34  275.43  298.43     NaN     NaN     NaN     NaN
#
#          9      10      11      12
# 7   138.99  146.40  149.90  150.78
# 8   206.45  220.76  216.51  217.56
# 9   300.21  306.50  335.45  340.10
# 10  241.55  228.17  247.87  229.87
# 11     NaN     NaN     NaN     NaN

# %%
dataset = pd.read_excel("poland_inflation_ratings.xlsx")
dataset.tail()
# Out:
#     Year       1       2       3       4       5       6       7       8  \
# 7   2019  102.94  105.65  117.65  119.18  125.65  129.98  137.68  137.78
# 8   2020  165.04  175.65  143.61  173.21  180.76  194.78  208.04  222.64
# 9   2021  242.67  233.56  234.81  258.26  257.86  267.60  280.60  292.43
# 10  2022  314.46  305.51  279.78  281.78  267.89  270.41  265.45  275.10
# 11  2023  238.45  265.34  275.43  298.43     NaN     NaN     NaN     NaN
#
#          9      10      11      12
# 7   138.99  146.40  149.90  150.78
# 8   206.45  220.76  216.51  217.56
# 9   300.21  306.50  335.45  340.10
# 10  241.55  228.17  247.87  229.87
# 11     NaN     NaN     NaN     NaN

# %%
dataset = dataset.melt(id_vars=['Year'], var_name='Month', value_name='Rate')
dataset.head()
# Out:
#    Year Month   Rate
# 0  2012     1  28.40
# 1  2013     1  27.87
# 2  2014     1  35.90
# 3  2015     1  42.60
# 4  2016     1  50.79

# %%
from pandas.tseries.offsets import MonthEnd
dataset['Date'] = pd.to_datetime(dataset[['Year', 'Month']].assign(DAY=1)) + MonthEnd(1)

# order ascending data values 
dataset = dataset.sort_values(by=['Date'])
dataset.head()
# Out:
#     Year Month   Rate       Date
# 0   2012     1  28.40 2012-01-31
# 12  2012     2  30.64 2012-02-29
# 24  2012     3  32.10 2012-03-31
# 36  2012     4  30.43 2012-04-30
# 48  2012     5  30.82 2012-05-31

# %%
df = dataset[['Date', 'Rate']]

# set date column as index
df.set_index('Date', inplace=True)

# drop NaN rows
df.dropna(subset=['Rate'], inplace=True)
df.tail()
# Out:
#               Rate
# Date
# 2022-12-31  229.87
# 2023-01-31  238.45
# 2023-02-28  265.34
# 2023-03-31  275.43
# 2023-04-30  298.43

# %%
df.describe().transpose()
# Out:
#       count        mean        std    min     25%     50%       75%    max
# Rate  136.0  118.020956  93.019956  26.56  43.275  74.495  197.6975  340.1

# %%
dataset.plot(x='Date', y='Rate', figsize=(9,4))
# Out:
# <Axes: xlabel='Date'>

# %%
time_series = df['Rate']
time_series.rolling(window=12).mean().plot(label='Rolling Mean')
time_series.rolling(window=12).std().plot(label='Rolling Std')
time_series.plot(figsize=(9,4))
plt.legend()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp = seasonal_decompose(time_series)
fig = decomp.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# ADF test
def adf_test(series):
    result = adfuller(series, autolag='AIC')
    print('1. ADF: ', result[0])
    print('2. P-value: ', result[1])
    print('3. Num of Lags: ', result[2])
    print('4. Num of Observations: ', result[3])
    print('5. Critial Values:')
    for key, value in result[4].items():
        print('\t', key, ': ', value)
        
    if result[1] <= 0.05:
        print('\nStrong evidence against the null hypothesis (H0), reject the null hypothesis. Data has no unit root and is stationary.')
    else:
        print('\nWeak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary.')

# run function
adf_test(df['Rate'])
# Out:
# 1. ADF:  0.3329050150472554
# 2. P-value:  0.9788047936029522
# 3. Num of Lags:  3
# 4. Num of Observations:  132
# 5. Critial Values:
# 	 1% :  -3.4808880719210005
# 	 5% :  -2.8836966192225284
# 	 10% :  -2.5785857598714417
#
# Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary.

# %%
from pmdarima.arima.utils import ndiffs
print(ndiffs(df['Rate'], test='adf'))
print(ndiffs(df['Rate'], test='kpss'))
print(ndiffs(df['Rate'], test='pp'))
# Out:
# 1
# 1
# 1

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig = plt.figure(figsize=(8,7))
ax1 = fig.add_subplot(2,1,1)
fig = plot_pacf(df, ax=ax1)
ax2 = fig.add_subplot(2,1,2)
fig = plot_acf(df, ax=ax2)
plt.show()

# %%
from pmdarima import auto_arima
stepwise_fit = auto_arima(df['Rate'], trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=984.463, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=989.975, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=991.727, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=991.766, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=994.047, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=990.400, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=992.437, Time=0.05 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=985.126, Time=0.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=984.813, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=993.642, Time=0.05 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=987.059, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=988.415, Time=0.05 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=986.685, Time=0.17 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=987.884, Time=0.06 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 0.863 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  136
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                -486.232
# Date:                Sat, 29 Apr 2023   AIC                            984.463
# Time:                        19:54:59   BIC                           1001.895
# Sample:                    01-31-2012   HQIC                           991.547
#                          - 04-30-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      2.5460      1.176      2.164      0.030       0.240       4.852
# ar.L1          0.3456      0.094      3.684      0.000       0.162       0.530
# ar.L2         -0.5914      0.112     -5.290      0.000      -0.811      -0.372
# ma.L1         -0.4508      0.083     -5.457      0.000      -0.613      -0.289
# ma.L2          0.8532      0.092      9.289      0.000       0.673       1.033
# sigma2        78.3065      7.213     10.856      0.000      64.169      92.444
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):                63.91
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):              21.64   Skew:                            -0.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.arima.model import ARIMA

# fitting the model
model = ARIMA(df['Rate'], order=(2,1,2), freq='M')
model_fit = model.fit()
model_fit.summary()
# Out:
# /home/zain/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Rate   No. Observations:                  136
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -488.942
# Date:                Sat, 29 Apr 2023   AIC                            987.884
# Time:                        19:54:59   BIC                           1002.410
# Sample:                    01-31-2012   HQIC                           993.787
#                          - 04-30-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3815      0.096      3.958      0.000       0.193       0.570
# ar.L2         -0.5694      0.103     -5.535      0.000      -0.771      -0.368
# ma.L1         -0.4654      0.083     -5.631      0.000      -0.627      -0.303
# ma.L2          0.8487      0.085      9.944      0.000       0.681       1.016
# sigma2        81.4996      7.901     10.315      0.000      66.014      96.985
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                66.29
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):              26.82   Skew:                            -0.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred = model_fit.predict(start=0, end=len(df) - 1, typ='levels', dynamic=False)

# %%
pred.tail()
# Out:
# 2022-12-31    238.233259
# 2023-01-31    232.727094
# 2023-02-28    242.211201
# 2023-03-31    264.806711
# 2023-04-30    278.653719
# Freq: M, Name: predicted_mean, dtype: float64

# %%
df['Rate'].plot(legend=True, label='Actual', figsize=(14,5))
pred.plot(legend=True, label='Forecast')
plt.title('Forecast vs Actual Results')
plt.show()

# %%
model_fit.plot_diagnostics(figsize=(9,9))
plt.show()

# %%
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(pred, df['Rate'], squared=False)
rmse
# Out:
# 9.319223762677236

# %%
# mean absolute error
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(pred, df['Rate'])
mae
# Out:
# 6.250332186202504

# %%
mape = np.mean(np.abs(df['Rate'] - pred) / df['Rate']) * 100
mape
# Out:
# 6.180628503614741

# %%
corr = np.corrcoef(pred, df['Rate'])[0,1]
corr
# Out:
# 0.9951554463171245

# %%
forecast = model_fit.predict(start=0, end=len(df) + 4, typ='levels', dynamic=False)

# %%
finaldata = forecast.tail(5)

# %%
finaldata.to_csv('predictionOutput.csv')
